# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
from lmfit import models

# %%
data = pd.read_csv('30 nov 1e data.csv', delimiter = ',')
voltage1 = np.array(data.iloc[:,4])
voltage2 = np.array(data.iloc[:,10])
time = np.array(data.iloc[:,3])

# %%
plt.plot(time, voltage1)
plt.plot(time, voltage2)
plt.xlabel('time (s)')
plt.ylabel('voltage (V)')
plt.show()

# %%
def gaussian(time, A, mu, sigma):
    return A* np.exp(-(time - mu)**2 / (2 * sigma**2))
def line(time, a, b):
    return a*time + b

# %%
gauss1 = models.Model(gaussian, prefix='p1_')
gauss2 = models.Model(gaussian, prefix='p2_')
gauss3 = models.Model(gaussian, prefix='p3_')
linear_function = models.Model(line, name="lijn")

# %%
curve1 = gauss1 + gauss2 + linear_function
params = curve1.make_params(p1_A = -1, p1_mu=-0.013, p1_sigma=0.001, p2_A = -1.2, p2_mu=-0.012, p2_sigma=0.003,a=-0.6,b=5.2)
fit_curve1 = curve1.fit(voltage1, params,time=time )

fit_curve1.plot()

# %%
fit_curve1
# Out:
# <h2> Model</h2> ((Model(gaussian, prefix='p1_') + Model(gaussian, prefix='p2_')) + Model(lijn)) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>109</td><td></td></tr><tr><td># data points</td><td>2482</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 3.49655509</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.00141332</td><td></td></tr><tr><td>Akaike info crit.</td><td>-16278.4336</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-16231.8990</td><td></td></tr><tr><td>R-squared</td><td> 0.98852291</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> p1_A </td><td>  0.38317698 </td><td>  0.00588408 </td><td> (1.54%) </td><td> -1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p1_mu </td><td> -0.01259807 </td><td>  1.0356e-05 </td><td> (0.08%) </td><td> -0.013 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p1_sigma </td><td>  7.7968e-04 </td><td>  1.3826e-05 </td><td> (1.77%) </td><td> 0.001 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p2_A </td><td> -1.17309919 </td><td>  0.00509546 </td><td> (0.43%) </td><td> -1.2 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p2_mu </td><td> -0.01173015 </td><td>  7.8635e-06 </td><td> (0.07%) </td><td> -0.012 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p2_sigma </td><td>  0.00276906 </td><td>  9.3067e-06 </td><td> (0.34%) </td><td> 0.003 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a </td><td> -10.6081812 </td><td>  0.11974279 </td><td> (1.13%) </td><td> -0.6 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> b </td><td>  4.91284923 </td><td>  0.00149039 </td><td> (0.03%) </td><td> 5.2 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>p1_sigma</td><td>p2_A</td><td>-0.7163</td></tr><tr><td>p1_A</td><td>p2_A</td><td>-0.7162</td></tr><tr><td>p2_A</td><td>p2_sigma</td><td>0.6056</td></tr><tr><td>a</td><td>b</td><td>0.5862</td></tr><tr><td>p1_A</td><td>p2_sigma</td><td>-0.5300</td></tr><tr><td>p2_A</td><td>p2_mu</td><td>0.5011</td></tr><tr><td>p1_A</td><td>p2_mu</td><td>-0.4593</td></tr><tr><td>p1_sigma</td><td>p2_mu</td><td>-0.4419</td></tr><tr><td>p1_sigma</td><td>p2_sigma</td><td>-0.4222</td></tr><tr><td>p2_mu</td><td>a</td><td>0.3540</td></tr><tr><td>p2_sigma</td><td>b</td><td>0.3417</td></tr><tr><td>p1_mu</td><td>p2_sigma</td><td>-0.3138</td></tr><tr><td>p1_A</td><td>p1_sigma</td><td>0.2882</td></tr><tr><td>p2_mu</td><td>b</td><td>0.2616</td></tr><tr><td>p1_mu</td><td>p2_mu</td><td>0.2194</td></tr><tr><td>p2_mu</td><td>p2_sigma</td><td>0.2125</td></tr><tr><td>p1_mu</td><td>p2_A</td><td>-0.1867</td></tr><tr><td>p2_sigma</td><td>a</td><td>-0.1691</td></tr><tr><td>p1_A</td><td>b</td><td>-0.1683</td></tr><tr><td>p2_A</td><td>a</td><td>0.1323</td></tr><tr><td>p1_sigma</td><td>b</td><td>-0.1261</td></tr><tr><td>p1_A</td><td>p1_mu</td><td>0.1182</td></tr><tr><td>p1_mu</td><td>a</td><td>0.1101</td></tr></table>

# %%
curve2 = gauss1 + gauss2 + linear_function + gauss3
params2 = curve2.make_params(p1_A = -0.5, p1_mu=-0.012, p1_sigma=0.001, p2_A = -1, p2_mu=-0.009, p2_sigma=0.001,a=-2,b=4.8, p3_A=0.4, p3_mu=-0.020, p3_sigma=0.002)
fit_curve2 = curve2.fit(voltage2, params2,time=time )

fit_curve2.plot()

# %%
fit_curve2
# Out:
# <h2> Model</h2> (((Model(gaussian, prefix='p1_') + Model(gaussian, prefix='p2_')) + Model(lijn)) + Model(gaussian, prefix='p3_')) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>291</td><td></td></tr><tr><td># data points</td><td>2482</td><td></td></tr><tr><td># variables</td><td>11</td><td></td></tr><tr><td>chi-square</td><td> 2.34186423</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.4774e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-17267.2960</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-17203.3110</td><td></td></tr><tr><td>R-squared</td><td> 0.99273009</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> p1_A </td><td> -0.42981748 </td><td>  0.00395610 </td><td> (0.92%) </td><td> -0.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p1_mu </td><td> -0.01315884 </td><td>  1.2087e-05 </td><td> (0.09%) </td><td> -0.012 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p1_sigma </td><td>  0.00107068 </td><td>  1.2220e-05 </td><td> (1.14%) </td><td> 0.001 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p2_A </td><td> -0.93314142 </td><td>  0.00321588 </td><td> (0.34%) </td><td> -1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p2_mu </td><td> -0.00903519 </td><td>  8.6540e-06 </td><td> (0.10%) </td><td> -0.009 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p2_sigma </td><td>  0.00192704 </td><td>  9.9992e-06 </td><td> (0.52%) </td><td> 0.002 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a </td><td>  9.09016584 </td><td>  0.30326927 </td><td> (3.34%) </td><td> -2 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> b </td><td>  4.83941636 </td><td>  0.00125371 </td><td> (0.03%) </td><td> 4.8 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p3_A </td><td>  0.35627538 </td><td>  0.00513209 </td><td> (1.44%) </td><td> 2 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p3_mu </td><td> -0.01840928 </td><td>  1.4998e-05 </td><td> (0.08%) </td><td> -0.02 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> p3_sigma </td><td>  0.00175361 </td><td>  3.0822e-05 </td><td> (1.76%) </td><td> 0.002 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a</td><td>p3_A</td><td>0.8788</td></tr><tr><td>a</td><td>p3_sigma</td><td>0.8562</td></tr><tr><td>p2_A</td><td>a</td><td>0.6942</td></tr><tr><td>p2_A</td><td>p3_A</td><td>0.6680</td></tr><tr><td>p3_A</td><td>p3_sigma</td><td>0.6665</td></tr><tr><td>p2_A</td><td>p3_sigma</td><td>0.6560</td></tr><tr><td>p2_mu</td><td>p2_sigma</td><td>-0.6447</td></tr><tr><td>p1_mu</td><td>p2_mu</td><td>0.6336</td></tr><tr><td>p1_sigma</td><td>p2_mu</td><td>0.6320</td></tr><tr><td>p1_mu</td><td>p2_sigma</td><td>-0.6071</td></tr><tr><td>p1_sigma</td><td>p2_sigma</td><td>-0.5065</td></tr><tr><td>p1_A</td><td>p2_A</td><td>0.5016</td></tr><tr><td>p1_A</td><td>a</td><td>0.4887</td></tr><tr><td>a</td><td>p3_mu</td><td>-0.4804</td></tr><tr><td>p1_A</td><td>p3_A</td><td>0.4578</td></tr><tr><td>p3_A</td><td>p3_mu</td><td>-0.4546</td></tr><tr><td>p2_sigma</td><td>p3_sigma</td><td>-0.4463</td></tr><tr><td>p2_sigma</td><td>p3_A</td><td>-0.3962</td></tr><tr><td>p1_A</td><td>p3_sigma</td><td>0.3930</td></tr><tr><td>p2_sigma</td><td>a</td><td>-0.3849</td></tr><tr><td>p1_mu</td><td>p1_sigma</td><td>0.3820</td></tr><tr><td>p3_mu</td><td>p3_sigma</td><td>-0.3391</td></tr><tr><td>p2_A</td><td>p3_mu</td><td>-0.3311</td></tr><tr><td>p1_A</td><td>p2_mu</td><td>-0.3029</td></tr><tr><td>a</td><td>b</ ...

# %% [markdown]
# ### omrekenen naar frequentie (nog niet klaar)

# %%
freq_curve1 = a*fit_curve1.params['p2_mu'].value + b
freq_curve2 = a*fit_curve2.params['p2_mu'].value + b

delta_f = 0.5*(freq_curve2-freq_curve1)
print(delta_f)

# %% [markdown]
# ### oude metingen

# %%
# omzetten naar frequentieas
delta_t = fit_curve2.params['p2_mu'].value - fit_curve2.params['p1_mu'].value
a = 172.4/delta_t
b = (-72-1770.884) - fit_curve1.params['p1_mu'].value*a

# %%
frequency = a*time + b

# %%
plt.plot(frequency, voltage1, label='voltage1')
plt.plot(frequency, voltage2, label='voltage2')
plt.legend(loc='lower left')
plt.xlabel('frequency in MHz in reference to voltage1')
# Out:
# Text(0.5, 0, 'frequency in MHz in reference to voltage1')
